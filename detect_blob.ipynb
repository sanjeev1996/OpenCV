# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjeev1996/OpenCV/blob/master/detect_blob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

bw = cv2.imread('detect_blob.png', 0)
height, width = bw.shape[0:2]
cv2_imshow(bw)

binary = np.zeros([height,width,1],'uint8')

thresh = 85

for row in range(0,height):
	for col in range(0, width):
		if bw[row][col]>thresh:
			binary[row][col]=255

cv2_imshow(binary)

ret, thresh = cv2.threshold(bw,thresh,255,cv2.THRESH_BINARY)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=541x760 at 0x7FA0156D7CF8>
# <PIL.Image.Image image mode=RGB size=541x760 at 0x7FA01567B6A0>
# <PIL.Image.Image image mode=L size=541x760 at 0x7FA0156D7CF8>
